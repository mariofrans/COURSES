# %%
# !wget -nc https://lazyprogrammer.me/course_files/airline_passengers.csv
# Out:
# --2021-02-06 20:50:11--  https://lazyprogrammer.me/course_files/airline_passengers.csv
# Resolving lazyprogrammer.me (lazyprogrammer.me)... 172.67.213.166, 104.21.23.210, 2606:4700:3031::6815:17d2, ...
# Connecting to lazyprogrammer.me (lazyprogrammer.me)|172.67.213.166|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2036 (2.0K) [text/csv]
# Saving to: ‘airline_passengers.csv’
#
# airline_passengers. 100%[===================>]   1.99K  --.-KB/s    in 0s
#
# 2021-02-06 20:50:12 (39.6 MB/s) - ‘airline_passengers.csv’ saved [2036/2036]

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('airline_passengers.csv', index_col='Month', parse_dates=True)

# %%
df.head()
# Out:
#             Passengers
# Month
# 1949-01-01         112
# 1949-02-01         118
# 1949-03-01         132
# 1949-04-01         129
# 1949-05-01         121

# %%
df.isna().sum()
# Out:
# Passengers    0
# dtype: int64

# %%
df.plot();

# %%
alpha = 0.2

# %%
df['EWMA'] = df['Passengers'].ewm(alpha=alpha, adjust=False).mean()

# %%
type(df['Passengers'].ewm(alpha=alpha, adjust=False))
# Out:
# pandas.core.window.ewm.ExponentialMovingWindow

# %%
df.plot();

# %%
manual_ewma = []
for x in df['Passengers'].to_numpy():
  if len(manual_ewma) > 0:
    xhat = alpha * x + (1 - alpha) * manual_ewma[-1]
  else:
    xhat = x
  manual_ewma.append(xhat)
df['Manual'] = manual_ewma

# %%
df.plot();

# %%
df.head()
# Out:
#             Passengers      EWMA    Manual
# Month
# 1949-01-01         112  112.0000  112.0000
# 1949-02-01         118  113.2000  113.2000
# 1949-03-01         132  116.9600  116.9600
# 1949-04-01         129  119.3680  119.3680
# 1949-05-01         121  119.6944  119.6944

# %%
df.drop('Manual', axis=1, inplace=True)

# %%
from statsmodels.tsa.holtwinters import SimpleExpSmoothing

# %%
ses = SimpleExpSmoothing(df['Passengers'])
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/base/tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)

# %%
# link to offset aliases docs
# https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html
df.index
# Out:
# DatetimeIndex(['1949-01-01', '1949-02-01', '1949-03-01', '1949-04-01',
#                '1949-05-01', '1949-06-01', '1949-07-01', '1949-08-01',
#                '1949-09-01', '1949-10-01',
#                ...
#                '1960-03-01', '1960-04-01', '1960-05-01', '1960-06-01',
#                '1960-07-01', '1960-08-01', '1960-09-01', '1960-10-01',
#                '1960-11-01', '1960-12-01'],
#               dtype='datetime64[ns]', name='Month', length=144, freq=None)

# %%
df.index.freq = 'MS'

# %%
ses = SimpleExpSmoothing(df['Passengers'])

# %%
res = ses.fit(smoothing_level=alpha, optimized=False)

# %%
res

# %%
res.predict(start=df.index[0], end=df.index[-1])
# Out:
# Month
# 1949-01-01    112.000000
# 1949-02-01    112.000000
# 1949-03-01    113.200000
# 1949-04-01    116.960000
# 1949-05-01    119.368000
#                  ...
# 1960-08-01    488.767616
# 1960-09-01    512.214093
# 1960-10-01    511.371274
# 1960-11-01    501.297019
# 1960-12-01    479.037615
# Freq: MS, Length: 144, dtype: float64

# %%
df['SES'] = res.predict(start=df.index[0], end=df.index[-1])

# %%
np.allclose(df['SES'], res.fittedvalues)
# Out:
# True

# %%
df.plot();

# %%
df.head()
# Out:
#             Passengers      EWMA      SES
# Month
# 1949-01-01         112  112.0000  112.000
# 1949-02-01         118  113.2000  112.000
# 1949-03-01         132  116.9600  113.200
# 1949-04-01         129  119.3680  116.960
# 1949-05-01         121  119.6944  119.368

# %%
df['SES-1'] = df['SES'].shift(-1)

# %%
### No!
df[['Passengers', 'EWMA', 'SES-1']].plot();

# %%
N_test = 12
train = df.iloc[:-N_test]
test = df.iloc[-N_test:]

# %%
ses = SimpleExpSmoothing(train['Passengers'])
res = ses.fit()

# %%
# boolean series to index df rows
train_idx = df.index <= train.index[-1]
test_idx = df.index > train.index[-1]

# %%
df.loc[train_idx, 'SESfitted'] = res.fittedvalues
df.loc[test_idx, 'SESfitted'] = res.forecast(N_test)
df[['Passengers', 'SESfitted']].plot();

# %%
res.params
# Out:
# {'damping_slope': nan,
#  'initial_level': 112.0,
#  'initial_seasons': array([], dtype=float64),
#  'initial_slope': nan,
#  'lamda': None,
#  'remove_bias': False,
#  'smoothing_level': 1.0,
#  'smoothing_seasonal': nan,
#  'smoothing_slope': nan,
#  'use_boxcox': False}

# %%
from statsmodels.tsa.holtwinters import Holt

# %%
holt = Holt(df['Passengers'])

# %%
res_h = holt.fit()

# %%
df['Holt'] = res_h.fittedvalues

# %%
df[['Passengers', 'Holt']].plot();

# %%
### No!
df['Holt-1'] = df['Holt'].shift(-1)
df[['Passengers', 'Holt-1']].plot();

# %%
holt = Holt(train['Passengers'])
res_h = holt.fit()
df.loc[train_idx, 'Holt'] = res_h.fittedvalues

# %%
df.loc[test_idx, 'Holt'] = res_h.forecast(N_test)

# %%
df[['Passengers', 'Holt']].plot();

# %%
from statsmodels.tsa.holtwinters import ExponentialSmoothing

# %%
hw = ExponentialSmoothing(train['Passengers'], \
                          trend='add', seasonal='add', seasonal_periods=12)
res_hw = hw.fit()
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/holtwinters.py:712: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   ConvergenceWarning)

# %%
df.loc[train_idx, 'HoltWinters'] = res_hw.fittedvalues

# %%
df.loc[test_idx, 'HoltWinters'] = res_hw.forecast(N_test)

# %%
df[['Passengers', 'HoltWinters']].plot();

# %%
def rmse(y, t):
  return np.sqrt(np.mean((y - t)**2))

# %%
def mae(y, t):
  return np.mean(np.abs(y - t))

# %%
print("Train RMSE:", rmse(train['Passengers'], res_hw.fittedvalues))
print("Test RMSE:", rmse(test['Passengers'], res_hw.forecast(N_test)))
# Out:
# Train RMSE: 11.86217892535535
# Test RMSE: 15.570830861607387

# %%
print("Train MAE:", mae(train['Passengers'], res_hw.fittedvalues))
print("Test MAE:", mae(test['Passengers'], res_hw.forecast(N_test)))
# Out:
# Train MAE: 8.942363646662809
# Test MAE: 10.455564918004228

# %%
hw = ExponentialSmoothing(train['Passengers'], \
                          trend='add', seasonal='mul', seasonal_periods=12)
res_hw = hw.fit()
df.loc[train_idx, 'HoltWinters'] = res_hw.fittedvalues
df.loc[test_idx, 'HoltWinters'] = res_hw.forecast(N_test)
df[['Passengers', 'HoltWinters']].plot();
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/holtwinters.py:712: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   ConvergenceWarning)

# %%
print("Train RMSE:", rmse(train['Passengers'], res_hw.fittedvalues))
print("Test RMSE:", rmse(test['Passengers'], res_hw.forecast(N_test)))
# Out:
# Train RMSE: 10.083139054535577
# Test RMSE: 17.485688905255643

# %%
print("Train MAE:", mae(train['Passengers'], res_hw.fittedvalues))
print("Test MAE:", mae(test['Passengers'], res_hw.forecast(N_test)))
# Out:
# Train MAE: 7.50408280898431
# Test MAE: 11.288272583732882

# %%
hw = ExponentialSmoothing(train['Passengers'], \
                          trend='mul', seasonal='mul', seasonal_periods=12)
res_hw = hw.fit()
df.loc[train_idx, 'HoltWinters'] = res_hw.fittedvalues
df.loc[test_idx, 'HoltWinters'] = res_hw.forecast(N_test)
df[['Passengers', 'HoltWinters']].plot();

# %%
print("Train RMSE:", rmse(train['Passengers'], res_hw.fittedvalues))
print("Test RMSE:", rmse(test['Passengers'], res_hw.forecast(N_test)))
# Out:
# Train RMSE: 9.61793106841632
# Test RMSE: 25.75758213574924

# %%
print("Train MAE:", mae(train['Passengers'], res_hw.fittedvalues))
print("Test MAE:", mae(test['Passengers'], res_hw.forecast(N_test)))
# Out:
# Train MAE: 7.111824747037166
# Test MAE: 20.79746214334362
