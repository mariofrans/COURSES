# %%
# !wget -nc https://lazyprogrammer.me/course_files/sp500_closefull.csv
# Out:
# File ‘sp500_closefull.csv’ already there; not retrieving.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('sp500_closefull.csv', index_col=0, parse_dates=True)

# %%
df.head()
# Out:
#                  CSCO    UAL       TROW  ...      UAA         BLK        PPL
# Date                                     ...
# 2010-01-04  24.690001  12.80  54.400002  ...  3.51000  238.580002  30.242558
# 2010-01-05  24.580000  13.91  55.009998  ...  3.61500  239.610001  29.851370
# 2010-01-06  24.420000  13.27  54.150002  ...  3.69500  234.669998  29.916569
# 2010-01-07  24.530001  13.55  54.110001  ...  3.65125  237.250000  29.627834
# 2010-01-08  24.660000  13.33  53.900002  ...  3.64375  238.919998  29.534695
#
# [5 rows x 480 columns]

# %%
df.dropna(axis=0, how='all', inplace=True)

# %%
df.shape
# Out:
# (2263, 480)

# %%
df.dropna(axis=1, how='any', inplace=True)

# %%
df.shape
# Out:
# (2263, 429)

# %%
df.isna().sum().sum()
# Out:
# 0

# %%
df_returns = pd.DataFrame()

# %%
for name in df.columns:
  df_returns[name] = np.log(df[name]).diff()

# %%
df_returns.head()
# Out:
#                 CSCO       UAL      TROW  ...       UAA       BLK       PPL
# Date                                      ...
# 2010-01-04       NaN       NaN       NaN  ...       NaN       NaN       NaN
# 2010-01-05 -0.004465  0.083163  0.011151  ...  0.029476  0.004308 -0.013019
# 2010-01-06 -0.006531 -0.047102 -0.015757  ...  0.021889 -0.020832  0.002182
# 2010-01-07  0.004494  0.020881 -0.000739  ... -0.011911  0.010934 -0.009698
# 2010-01-08  0.005286 -0.016369 -0.003889  ... -0.002056  0.007014 -0.003149
#
# [5 rows x 429 columns]

# %%
df_returns['SPY'] = df_returns['SPY'].shift(-1)
df_returns['SPY'].tail()
# Out:
# Date
# 2018-12-21   -0.026778
# 2018-12-24    0.049290
# 2018-12-26    0.007648
# 2018-12-27   -0.001291
# 2018-12-28         NaN
# Name: SPY, dtype: float64

# %%
Ntest = 1000
train = df_returns.iloc[1:-Ntest]
test = df_returns.iloc[-Ntest:-1]

# %%
df_returns.columns
# Out:
# Index(['CSCO', 'UAL', 'TROW', 'ISRG', 'PRGO', 'TPR', 'DVN', 'MRO', 'BA',
#        'VRTX',
#        ...
#        'M', 'CRM', 'PGR', 'WAT', 'BWA', 'LRCX', 'NWL', 'UAA', 'BLK', 'PPL'],
#       dtype='object', length=429)

# %%
# x_cols = df.columns.drop('SPY')
x_cols = ['AAPL', 'MSFT', 'AMZN', 'JNJ', 'V', 'PG', 'JPM']
x_cols
# Out:
# ['AAPL', 'MSFT', 'AMZN', 'JNJ', 'V', 'PG', 'JPM']

# %%
Xtrain = train[x_cols]
Ytrain = train['SPY']
Xtest = test[x_cols]
Ytest = test['SPY']

# %%
Xtrain.head()
# Out:
#                 AAPL      MSFT      AMZN  ...         V        PG       JPM
# Date                                      ...
# 2010-01-05  0.001727  0.000323  0.005883  ... -0.011525  0.000327  0.019185
# 2010-01-06 -0.016034 -0.006156 -0.018282  ... -0.013519 -0.004755  0.005479
# 2010-01-07 -0.001850 -0.010454 -0.017160  ...  0.009264 -0.005438  0.019615
# 2010-01-08  0.006626  0.006873  0.026717  ...  0.002762 -0.001323 -0.002459
# 2010-01-11 -0.008861 -0.012802 -0.024335  ... -0.002878 -0.003979 -0.003363
#
# [5 rows x 7 columns]

# %%
Ytrain.head()
# Out:
# Date
# 2010-01-05    0.000704
# 2010-01-06    0.004212
# 2010-01-07    0.003322
# 2010-01-08    0.001396
# 2010-01-11   -0.009370
# Name: SPY, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(Xtrain, Ytrain)
model.score(Xtrain, Ytrain), model.score(Xtest, Ytest)
# Out:
# (0.008271754178782342, -0.011369618185063102)

# %%
# Direction
Ptrain = model.predict(Xtrain)
Ptest = model.predict(Xtest)
np.mean(np.sign(Ptrain) == np.sign(Ytrain)), np.mean(np.sign(Ptest) == np.sign(Ytest))
# Out:
# (0.528526148969889, 0.5285285285285285)

# %%
set(np.sign(Ptrain)), set(np.sign(Ptest))
# Out:
# ({-1.0, 1.0}, {-1.0, 1.0})

# %%
train_idx = df.index <= train.index[-1]
test_idx = df.index > train.index[-1]

train_idx[0] = False
test_idx[-1] = False

# %%
df_returns['Position'] = 0 # create new column
df_returns.loc[train_idx,'Position'] = (Ptrain > 0)
df_returns.loc[test_idx,'Position'] = (Ptest > 0)

# %%
df_returns['AlgoReturn'] = df_returns['Position'] * df_returns['SPY']

# %%
# Total algo log return train
df_returns.iloc[1:-Ntest]['AlgoReturn'].sum()
# Out:
# 0.5477174926058384

# %%
# Total algo log return test
df_returns.iloc[-Ntest:-1]['AlgoReturn'].sum()
# Out:
# 0.3037759916492

# %%
# Total return buy-and-hold train
Ytrain.sum()
# Out:
# 0.5863972019814705

# %%
# Total return buy-and-hold test
Ytest.sum()
# Out:
# 0.19307543946998518

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(C=10)
Ctrain = (Ytrain > 0)
Ctest = (Ytest > 0)
model.fit(Xtrain, Ctrain)
model.score(Xtrain, Ctrain), model.score(Xtest, Ctest)
# Out:
# (0.5586370839936609, 0.5285285285285285)

# %%
Ptrain = model.predict(Xtrain)
Ptest = model.predict(Xtest)
set(Ptrain), set(Ptest)
# Out:
# ({False, True}, {False, True})

# %%
df_returns.loc[train_idx,'Position'] = Ptrain
df_returns.loc[test_idx,'Position'] = Ptest
df_returns['AlgoReturn'] = df_returns['Position'] * df_returns['SPY']

# %%
# Total algo log return train
df_returns.iloc[1:-Ntest]['AlgoReturn'].sum()
# Out:
# 0.5905718759742236

# %%
# Total algo log return test
df_returns.iloc[-Ntest:-1]['AlgoReturn'].sum()
# Out:
# 0.19680747922142316

# %%
# Total return buy-and-hold
Ytrain.sum(), Ytest.sum()
# Out:
# (0.5863972019814705, 0.19307543946998518)

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(random_state=2)
model.fit(Xtrain, Ctrain)
model.score(Xtrain, Ctrain), model.score(Xtest, Ctest)
# Out:
# (1.0, 0.5255255255255256)

# %%
Ptrain = model.predict(Xtrain)
Ptest = model.predict(Xtest)

# %%
df_returns.loc[train_idx,'Position'] = Ptrain
df_returns.loc[test_idx,'Position'] = Ptest

# %%
df_returns['AlgoReturn'] = df_returns['Position'] * df_returns['SPY']

# %%
# Total algo log return train
df_returns.iloc[1:-Ntest]['AlgoReturn'].sum()
# Out:
# 4.706503557502184

# %%
# Total algo log return test
df_returns.iloc[-Ntest:-1]['AlgoReturn'].sum()
# Out:
# 0.3839643540537523

# %%
# Total return buy-and-hold
Ytrain.sum(), Ytest.sum()
# Out:
# (0.5863972019814705, 0.19307543946998518)
